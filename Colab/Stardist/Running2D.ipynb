# %% [markdown]
# ## Install all packages

# %%
# !sudo apt-get install python3.9
# !pip install pyparsing==2.2.1 tensorflow-gpu==1.15.0 scikit-image==0.17.2 scikit-learn==0.24.1 scipy==1.1.0 imgaug==0.4.0 Ipython==7.20.0 keras==2.2.4 opencv-python==4.4.0.46 jupyter==1.0.0 numpy==1.21.0 h5py==2.10.0 ipyfilechooser==0.4.2 stardist==0.7.3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9-minimal
# Suggested packages:
#   python3.9-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9 python3.9-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 32 not upgraded.
# Need to get 4,916 kB of archives.
# After this operation, 19.1 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.9-minimal amd64 3.9.14-1+bionic1 [806 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.9-minimal amd64 3.9.14-1+bionic1 [1,937 kB]
# ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:44
# 🔁 Restarting kernel...

# %%
# !conda install cudatoolkit
# !conda install cudnn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15.2|       ha878542_0         150 KB  conda-forge
#     certifi-2022.6.15.2        |     pyhd8ed1ab_0         154 KB  conda-forge
#     cudatoolkit-11.1.1         |      ha002fc5_10        1.20 GB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.20 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-ha002fc5_10
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.6.15-ha878542_0 --> 2022.6.15.2-ha878542_0
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd "/content/drive/MyDrive/Stardist/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Stardist

# %% [markdown]
# ## Loading
#
# The first step is to load the libraries and functions we need.

# %%
from utils import running_parameters_stardist_interface_2D, running_stardist_2D
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Setting parameters
#
# The second step is to define the parameters required to run one or several classifiers.

# %%
nb_runnings = 1

parameters = running_parameters_stardist_interface_2D(nb_runnings)
# Out:
# Input directory
# FileChooser(path='./datasets', filename='', title='HTML(value='', layout=Layout(display='none'))', show_hidden…
# Input model
# FileChooser(path='./models', filename='', title='HTML(value='', layout=Layout(display='none'))', show_hidden='…
# Output directory
# FileChooser(path='./datasets', filename='', title='HTML(value='', layout=Layout(display='none'))', show_hidden…
# ...

# %% [markdown]
# ## Running Stardist
#
# Now, images can be segmented.

# %%
running_stardist_2D(nb_runnings, parameters)
# Out:
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.61358, nms_thresh=0.3.
# Processing image  1  of  3
# Processing image  2  of  3
# Processing image  3  of  3
